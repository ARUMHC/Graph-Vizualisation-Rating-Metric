# %%
import sys
from pathlib import Path
# sys.path.insert(0,str(Path(r'C:\Users\ku51015\CHMURA\mystuff\Graph-Vizualisation-Rating-Metric').resolve()))
sys.path.insert(0,str(Path(r'C:\Users\Kinga\Desktop\MAGISTERKA\Graph-Vizualisation-Rating-Metric-3').resolve()))

from graph_generating_script import *
from graph_metric_script import *
import matplotlib.pyplot as plt
import igraph as ig
import numpy as np
import pickle

# %%
# # List of layouts

# #! change made so that 5 random layouts are generated

# np.random.seed(212)
# def draw_five_layouts(G, graph_id, node_size=200):
#     G_ig = ig.Graph.TupleList(nx.to_edgelist(G), directed=False)
#     missing_vertices = set(G.nodes()) - set(G_ig.vs['name'])
#     G_ig.add_vertices(list(missing_vertices))
#     layouts = [
#         # nx.circular_layout(G),
#         nx.kamada_kawai_layout(G),
#         nx.random_layout(G),
#         nx.random_layout(G),
#         nx.random_layout(G),
#         nx.random_layout(G),
#         nx.random_layout(G),
#         # G_ig.layout('davidson_harel'),
#         # G_ig.layout('graphopt'),
#         G_ig.layout('lgl')
#     ]
#     layout_names = ['kamada_kawai','random_no1', 'random_no2', 'random_no3', 'random_no4', 'random_no5', 'lgl']
#     # Create a 2x5 subplot
#     fig, axes = plt.subplots(1, 7, figsize=(20, 3.5))

#     # Draw the graph using each layout
#     for ax, pos, layout_name in zip(axes.flatten(), layouts, layout_names):
#         # pos = layout(G)
#         nx.draw(G, pos, with_labels=True, edge_color='gray', node_size=node_size, font_size=10, ax=ax)
#         ax.set_title(layout_name)

#     fig.savefig(f'layouts_img/{graph_id}_all_layouts_img.png')
#     plt.show()
#     return layouts

# %%
# def save_posdfs(G, layouts, graph_id):
#     layout_names = ['kamada_kawai','random_no1', 'random_no2', 'random_no3', 'random_no4', 'random_no5', 'lgl']

#     # Save each layout to a file
#     for layout, name in zip(layouts, layout_names):
#         # if name in ['random', 'kamada_kawai']:
#         if name.startswith('random') or name == 'kamada_kawai':
#             posdf = pd.DataFrame.from_dict(layout, orient='index', columns=['X', 'Y'])
#         else:
#             posdf = pd.DataFrame(layout.coords, columns=['X', 'Y'])

#         posdf.to_csv(f'pos_dfs/{graph_id}_{name}.csv', index=False)

#     with open(f'graph_objects/graph_{graph_id}.pkl', 'wb') as f:
#         pickle.dump(G, f)

# %% [markdown]
# # Example

# %%
np.random.seed(212)

# G = nx.erdos_renyi_graph(8, .4)
G = nx.barabasi_albert_graph(8, 3)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=200, font_size=10)

# %%
layouts = draw_five_layouts(G, 0)
save_posdfs(G, layouts, 0)

# %%
np.random.seed(212)

G = nx.barabasi_albert_graph(10, 5)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 1)
save_posdfs(G, layouts, 1)

# %% [markdown]
# # 2

# %%
np.random.seed(212)

G = nx.barabasi_albert_graph(10, 2)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 2)
save_posdfs(G, layouts, 2)

# %%
np.random.seed(212)

G = nx.barabasi_albert_graph(15, 1)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 3)
save_posdfs(G, layouts, 3)

# %%
np.random.seed(212)

G = nx.barabasi_albert_graph(6, 4)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 4)
save_posdfs(G, layouts, 4)

# %%
G = nx.barabasi_albert_graph(4, 3)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 5)
save_posdfs(G, layouts, 5)

# %%
G = nx.barabasi_albert_graph(8, 1)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 6)
save_posdfs(G, layouts, 6)

# %%
G = nx.barabasi_albert_graph(7, 4)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 7)
save_posdfs(G, layouts, 7)

# %%
G = nx.barabasi_albert_graph(7, 2)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 8)
save_posdfs(G, layouts, 8)

# %%
G = nx.barabasi_albert_graph(6, 3)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 9)
save_posdfs(G, layouts, 9)

# %%
np.random.seed(212)

# G = nx.erdos_renyi_graph(8, .4)
G = nx.barabasi_albert_graph(8, 3)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=200, font_size=10)

# %%
layouts = draw_five_layouts(G, 10)
save_posdfs(G, layouts, 10)

# %%
np.random.seed(212)

G = nx.barabasi_albert_graph(10, 5)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 11)
save_posdfs(G, layouts, 11)

# %%
np.random.seed(212)

G = nx.barabasi_albert_graph(10, 2)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 12)
save_posdfs(G, layouts, 12)

# %%
np.random.seed(212)

G = nx.barabasi_albert_graph(15, 1)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 13)
save_posdfs(G, layouts, 13)

# %%
np.random.seed(212)

G = nx.barabasi_albert_graph(8, 1)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 14)
save_posdfs(G, layouts, 14)

# %%
np.random.seed(212)

G = nx.barabasi_albert_graph(6, 4)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 15)
save_posdfs(G, layouts, 15)

# %%
G = nx.barabasi_albert_graph(4, 3)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 16)
save_posdfs(G, layouts, 16)

# %%
G = nx.barabasi_albert_graph(8, 1)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 17)
save_posdfs(G, layouts, 17)

# %%
G = nx.barabasi_albert_graph(7, 4)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 18)
save_posdfs(G, layouts, 18)

# %%
G = nx.barabasi_albert_graph(7, 2)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 19)
save_posdfs(G, layouts, 19)

# %%
G = nx.barabasi_albert_graph(6, 3)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 20)
save_posdfs(G, layouts, 20)
