# %%
import sys
from pathlib import Path
# sys.path.insert(0,str(Path(r'C:\Users\ku51015\CHMURA\mystuff\Graph-Vizualisation-Rating-Metric-randoms').resolve()))
sys.path.insert(0,str(Path(r'C:\Users\Kinga\Desktop\MAGISTERKA\Graph-Vizualisation-Rating-Metric-3').resolve()))

from graph_generating_script import *
from graph_metric_script import *
import matplotlib.pyplot as plt
import igraph as ig
import numpy as np
import pickle
import os
# List of layouts
np.random.seed(212)

# %% [markdown]
# # Example

# %%
# %load_ext autoreload
# %autoreload 3
from graph_metric_script import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
np.random.seed(212)

G = nx.erdos_renyi_graph(8, .4)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 0)
save_posdfs(G, layouts, 0)
# Out:
# {0: array([-1.        ,  0.99991321]), 1: array([-0.99985028,  0.99995449]), 2: array([-0.46514157, -0.5752164 ]), 3: array([-0.9997237 ,  0.99999972]), 4: array([-0.99972423,  1.        ]), 5: array([1.        , 0.14862209]), 6: array([-0.52028603, -1.        ]), 7: array([-0.52065775, -0.99999745])}

# %%
np.random.seed(212)

G = nx.erdos_renyi_graph(7, .4)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 1)
save_posdfs(G, layouts, 1)
# Out:
# {0: array([ 1.        , -0.99990873]), 1: array([ 0.99991635, -1.        ]), 2: array([-1.        , -0.35342172]), 3: array([-0.10398117,  0.99999205]), 4: array([-0.99995558, -0.35323555]), 5: array([-0.05908273,  0.00957191]), 6: array([-0.10398239,  1.        ])}

# %% [markdown]
# # 2

# %%
np.random.seed(212)

G = nx.erdos_renyi_graph(10, .3)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 2)
save_posdfs(G, layouts, 2)
# Out:
# {0: array([0.99953239, 0.89343804]), 1: array([1.       , 0.8925591]), 2: array([0.99944694, 0.89394278]), 3: array([0.99942828, 0.89286762]), 4: array([0.99864333, 0.89404632]), 5: array([ 0.41053253, -0.17735663]), 6: array([0.99946522, 0.8939493 ]), 7: array([-0.56691499,  1.        ]), 8: array([-1.       ,  0.6860408]), 9: array([ 0.42702906, -1.        ])}

# %%
np.random.seed(212)

G = nx.erdos_renyi_graph(8, .6)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 3)
save_posdfs(G, layouts, 3)
# Out:
# {0: array([0.99991491, 1.        ]), 1: array([-0.77489724, -0.88010306]), 2: array([-0.77489793, -0.88010242]), 3: array([-0.77490225, -0.88010292]), 4: array([1.       , 0.9999132]), 5: array([-0.77477949, -0.88030871]), 6: array([ 0.03084949, -0.47330257]), 7: array([-1., -1.])}

# %%
np.random.seed(212)

G = nx.erdos_renyi_graph(5, 1)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 4)
save_posdfs(G, layouts, 4)
# Out:
# {0: array([-1.        ,  0.34813893]), 1: array([ 0.55229734, -1.        ]), 2: array([ 0.07334628, -0.34505331]), 3: array([1., 1.]), 4: array([-0.80855491,  0.065937  ])}

# %%
G = nx.erdos_renyi_graph(7, .5)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 5)
save_posdfs(G, layouts, 5)
# Out:
# {0: array([-0.99952692, -0.99995635]), 1: array([-0.99948189, -1.        ]), 2: array([-1.        , -0.99974829]), 3: array([ 1.        , -0.07563709]), 4: array([ 0.96271751, -0.26326383]), 5: array([-0.12630759,  0.99992527]), 6: array([-0.12558373,  1.        ])}

# %%
G = nx.erdos_renyi_graph(5, .2)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 6)
save_posdfs(G, layouts, 6)
# Out:
# {0: array([0.48334934, 1.        ]), 1: array([-0.72103697, -0.50733557]), 2: array([ 1., -1.]), 3: array([-0.20092094,  0.17297756]), 4: array([-1.        , -0.60984546])}

# %%
G = nx.erdos_renyi_graph(5, .5)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 7)
save_posdfs(G, layouts, 7)
# Out:
# {0: array([ 0.93611212, -1.        ]), 1: array([ 0.93625922, -0.99980007]), 2: array([ 1.        , -0.10656995]), 3: array([-1.        , -0.10809377]), 4: array([-0.91202734,  1.        ])}

# %%
G = nx.erdos_renyi_graph(5, .7)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 8)
save_posdfs(G, layouts, 8)
# Out:
# {0: array([-0.01308611, -0.42771547]), 1: array([-0.26239198, -1.        ]), 2: array([-1.        ,  0.71191698]), 3: array([0.66661756, 0.56620118]), 4: array([1., 1.])}

# %%
# %load_ext autoreload
# %autoreload 3
from graph_metric_script import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
G = nx.erdos_renyi_graph(7, .3)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 9)
save_posdfs(G, layouts, 9)
# Out:
# {0: array([ 1., -1.]), 1: array([-0.99801724,  0.99922622]), 2: array([-0.99804954,  0.99925854]), 3: array([-1.,  1.]), 4: array([-0.99991772,  0.99996889]), 5: array([-0.9989857 ,  0.99961542]), 6: array([-0.99896927,  0.99959932])}

# %%
np.random.seed(212)

G = nx.erdos_renyi_graph(8, .4)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 10)
save_posdfs(G, layouts, 10)

# %%
np.random.seed(212)

G = nx.erdos_renyi_graph(7, .4)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 11)
save_posdfs(G, layouts, 11)

# %%
np.random.seed(212)

G = nx.erdos_renyi_graph(10, .3)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 12)
save_posdfs(G, layouts, 12)

# %%
np.random.seed(212)

G = nx.erdos_renyi_graph(8, .6)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 13)
save_posdfs(G, layouts, 13)

# %%
np.random.seed(212)

G = nx.erdos_renyi_graph(5, 1)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 14)
save_posdfs(G, layouts, 14)

# %%
G = nx.erdos_renyi_graph(7, .5)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 15)
save_posdfs(G, layouts, 15)

# %%
G = nx.erdos_renyi_graph(5, .2)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 16)
save_posdfs(G, layouts, 16)

# %%
G = nx.erdos_renyi_graph(5, .5)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 17)
save_posdfs(G, layouts, 17)

# %%
G = nx.erdos_renyi_graph(5, .7)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 18)
save_posdfs(G, layouts, 18)

# %%
G = nx.erdos_renyi_graph(4, .5)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 19)
save_posdfs(G, layouts, 19)

# %%
G = nx.erdos_renyi_graph(6, .3)
plt.figure(figsize=(3,3))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layouts = draw_five_layouts(G, 20)
save_posdfs(G, layouts, 20)
