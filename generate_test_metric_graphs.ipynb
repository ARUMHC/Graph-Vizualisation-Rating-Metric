# %% [markdown]
# # TODOS
#
# * DONE mysle ze generalnie tez wygenerowac wiecej grafow dla kazdej kategorii
# * napisac maszynke do zczytywania lamb z macierzy korelacji
# * jakos to zbic we wzor metryki? I guess? moze te wartosci componentow wszystkie przeskalowac od 0 do 1 * lambda ?
# * napisac test casy - z kazdej kategorii wygenerowac idk 5 grafow, narysowac to jako kamda_kawai (ground truth)
# * recznie pozmieniac niektore wspolrzedne zeby zrobic 2 znacznie gorsze layouty
# * policzyc score dla kazdego layoutu z roznych zestawow lambd (BA, ER, WS, RGG, Whole) i zobaczyc co tam sie dzieje w ogole

# %%
import sys
from pathlib import Path
# sys.path.insert(0,str(Path(r'C:\Users\ku51015\CHMURA\mystuff\Graph-Vizualisation-Rating-Metric-randoms').resolve()))
sys.path.insert(0,str(Path(r'C:\Users\Kinga\Desktop\MAGISTERKA\Graph-Vizualisation-Rating-Metric-3').resolve()))

from graph_generating_script import *
from graph_metric_script import *
import matplotlib.pyplot as plt
import igraph as ig
import numpy as np
import pickle
import os
# List of layouts
np.random.seed(212)

# %% [markdown]
# # Generating testing graph

# %% [markdown]
# # WS

# %% [markdown]
# ### test 5

# %%
np.random.seed(212)

# G = nx.erdos_renyi_graph(8, .3)
G = nx.watts_strogatz_graph(6, 3, 0.5)
# nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)
plt.figure(figsize=(3, 3))
layout= nx.kamada_kawai_layout(G)
nx.draw(G, pos=layout, node_color='lightblue', with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
#todo CHANGE THIS before running
test_no = 5
category = 'WS'

layout= nx.kamada_kawai_layout(G)
posdf = pd.DataFrame.from_dict(layout, orient='index', columns=['X', 'Y'])
file_path = f'tests/pos_dfs/posdf_{category}_{test_no}_kamada_kawai.csv'
posdf.to_csv(file_path, index=False)

with open(f'tests/graph_objects/graph_{category}_{test_no}_kamada_kawai.pkl', 'wb') as f:
    pickle.dump(G, f)

posdf
# Out:
#           X         Y
# 0  0.403799 -0.333032
# 1  0.521555  0.415067
# 2 -0.600513  0.962640
# 3 -1.000000 -0.272032
# 4 -0.264009  0.170118
# 5  0.939169 -0.942761

# %%
posdf_worse = posdf.copy(deep=True)

#here conduct changes
posdf_worse.at[5, 'X'] = -.9
posdf_worse.at[5, 'Y'] = .9
posdf_worse.at[4, 'X'] = .8
posdf_worse.at[0, 'X'] = -.7
posdf_worse.at[0, 'Y'] = .2

positions = {i: (posdf_worse.loc[i, 'X'], posdf_worse.loc[i, 'Y']) for i in range(len(posdf_worse))}

# Draw the graph
plt.figure(figsize=(3, 3))
nx.draw(G, pos=positions, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500, font_size=10)
plt.title('Graph with Positions from posd_better DataFrame')
plt.show()

# %%
file_path = f'tests/pos_dfs/posdfworse_{category}_{test_no}_kamada_kawai.csv'
posdf_worse.to_csv(file_path, index=False)

# %% [markdown]
# ### Test 6

# %%
np.random.seed(212)

# G = nx.erdos_renyi_graph(8, .3)
G = nx.watts_strogatz_graph(10, 3, 0.8)
# nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)
plt.figure(figsize=(3, 3))
layout= nx.kamada_kawai_layout(G)
nx.draw(G, pos=layout, node_color='lightblue', with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
#todo CHANGE THIS before running
test_no = 6
category = 'WS'

layout= nx.kamada_kawai_layout(G)
posdf = pd.DataFrame.from_dict(layout, orient='index', columns=['X', 'Y'])
file_path = f'tests/pos_dfs/posdf_{category}_{test_no}_kamada_kawai.csv'
posdf.to_csv(file_path, index=False)

with open(f'tests/graph_objects/graph_{category}_{test_no}_kamada_kawai.pkl', 'wb') as f:
    pickle.dump(G, f)

posdf
# Out:
#           X         Y
# 0 -0.006273  0.644940
# 1  0.405558 -0.145040
# 2  0.766674 -0.237726
# 3 -0.025377  1.000000
# 4 -0.634899 -0.392192
# 5 -0.394827 -0.103424
# 6  0.007994  0.275729
# 7 -0.268989 -0.421121
# 8  0.145697 -0.494061
# 9  0.004444 -0.127104

# %%
posdf_worse = posdf.copy(deep=True)

#here conduct changes
posdf_worse.at[4, 'X'] = .8
posdf_worse.at[4, 'Y'] = .5
posdf_worse.at[0, 'X'] = -.7


positions = {i: (posdf_worse.loc[i, 'X'], posdf_worse.loc[i, 'Y']) for i in range(len(posdf_worse))}

# Draw the graph
plt.figure(figsize=(3, 3))
nx.draw(G, pos=positions, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500, font_size=10)
plt.title('Graph with Positions from posd_better DataFrame')
plt.show()

# %%
file_path = f'tests/pos_dfs/posdfworse_{category}_{test_no}_kamada_kawai.csv'
posdf_worse.to_csv(file_path, index=False)

# %% [markdown]
# # RGG

# %% [markdown]
# ### test 7

# %%
np.random.seed(212)

# G = nx.erdos_renyi_graph(8, .3)
G = nx.random_regular_graph(3, 6)
# nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)
plt.figure(figsize=(3, 3))
layout= nx.kamada_kawai_layout(G)
nx.draw(G, pos=layout, node_color='lightblue', with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
#todo CHANGE THIS before running
test_no = 7
category = 'RGG'

layout= nx.kamada_kawai_layout(G)
posdf = pd.DataFrame.from_dict(layout, orient='index', columns=['X', 'Y'])
file_path = f'tests/pos_dfs/posdf_{category}_{test_no}_kamada_kawai.csv'
posdf.to_csv(file_path, index=False)

with open(f'tests/graph_objects/graph_{category}_{test_no}_kamada_kawai.pkl', 'wb') as f:
    pickle.dump(G, f)

posdf
# Out:
#           X         Y
# 1  0.610782 -0.514365
# 2  0.990747  0.372507
# 0 -1.000000  0.276009
# 4 -0.570442 -0.866474
# 3  0.120601  0.789355
# 5 -0.151687 -0.057032

# %%
posdf_worse = posdf.copy(deep=True)

#here conduct changes
posdf_worse.at[5, 'Y'] = .9
posdf_worse.at[1, 'Y'] = .9
posdf_worse.at[1, 'X'] = -.7


positions = {i: (posdf_worse.loc[i, 'X'], posdf_worse.loc[i, 'Y']) for i in range(len(posdf_worse))}

# Draw the graph
plt.figure(figsize=(3, 3))
nx.draw(G, pos=positions, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500, font_size=10)
plt.title('Graph with Positions from posd_better DataFrame')
plt.show()

# %%
file_path = f'tests/pos_dfs/posdfworse_{category}_{test_no}_kamada_kawai.csv'
posdf_worse.to_csv(file_path, index=False)

# %% [markdown]
# ### test 8

# %%
np.random.seed(212)

# G = nx.erdos_renyi_graph(8, .3)
G = nx.random_regular_graph(2, 4)
# nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)
plt.figure(figsize=(3, 3))
layout= nx.kamada_kawai_layout(G)
nx.draw(G, pos=layout, node_color='lightblue', with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
#todo CHANGE THIS before running
test_no = 8
category = 'RGG'

layout= nx.kamada_kawai_layout(G)
posdf = pd.DataFrame.from_dict(layout, orient='index', columns=['X', 'Y'])
file_path = f'tests/pos_dfs/posdf_{category}_{test_no}_kamada_kawai.csv'
posdf.to_csv(file_path, index=False)

with open(f'tests/graph_objects/graph_{category}_{test_no}_kamada_kawai.pkl', 'wb') as f:
    pickle.dump(G, f)

posdf
# Out:
#               X             Y
# 0  1.000000e+00  3.881992e-08
# 2 -3.333294e-08  1.000000e+00
# 1 -1.000000e+00 -3.686098e-08
# 3  3.404520e-08 -1.000000e+00

# %%
posdf_worse = posdf.copy(deep=True)

#here conduct changes
posdf_worse.at[1, 'Y'] = .8
posdf_worse.at[1, 'X'] = .3
# posdf_worse.at[0, 'X'] = -.2
# posdf_worse.at[0, 'Y'] = .3


positions = {i: (posdf_worse.loc[i, 'X'], posdf_worse.loc[i, 'Y']) for i in range(len(posdf_worse))}

# Draw the graph
plt.figure(figsize=(3, 3))
nx.draw(G, pos=positions, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500, font_size=10)
plt.title('Graph with Positions from posd_better DataFrame')
plt.show()

# %%
file_path = f'tests/pos_dfs/posdfworse_{category}_{test_no}_kamada_kawai.csv'
posdf_worse.to_csv(file_path, index=False)

# %% [markdown]
# # ER

# %% [markdown]
# ### test 1

# %%
np.random.seed(212)

G = nx.erdos_renyi_graph(8, .3)
# nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)
plt.figure(figsize=(3, 3))
layout= nx.kamada_kawai_layout(G)
nx.draw(G, pos=layout, node_color='lightblue', with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
test_no = 2
layout= nx.kamada_kawai_layout(G)
posdf = pd.DataFrame.from_dict(layout, orient='index', columns=['X', 'Y'])
file_path = f'tests/pos_dfs/posdf_ER_{test_no}_kamada_kawai.csv'
posdf.to_csv(file_path, index=False)

with open(f'tests/graph_objects/graph_ER_{test_no}_kamada_kawai.pkl', 'wb') as f:
    pickle.dump(G, f)

# %%
posdf
# Out:
#           X         Y
# 0  0.559596  0.282473
# 1 -0.428826  0.064015
# 2  1.000000  0.550629
# 3 -0.724729  0.526469
# 4  0.125096 -0.050179
# 5  0.311884 -0.575633
# 6  0.000005 -0.500563
# 7 -0.843025 -0.297212

# %%
posdf_worse = posdf.copy(deep=True)

#here conduct changes
posdf_worse.at[4, 'X'] = 0.559596	
posdf_worse.at[4, 'Y'] = 0.482473
posdf_worse.at[0, 'X'] = 0.125096	
posdf_worse.at[0, 'Y'] = -0.050179
posdf_worse.at[1, 'X'] = 0.511884
posdf_worse.at[1, 'Y'] = -0.575633

# %%
positions = {i: (posdf_worse.loc[i, 'X'], posdf_worse.loc[i, 'Y']) for i in range(len(posdf_worse))}

# Draw the graph
plt.figure(figsize=(3, 3))
nx.draw(G, pos=positions, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500, font_size=10)
plt.title('Graph with Positions from posd_better DataFrame')
plt.show()

# %%
file_path = f'tests/pos_dfs/posdfworse_ER_{test_no}_kamada_kawai.csv'
posdf_worse.to_csv(file_path, index=False)

# %% [markdown]
# ## BA tests

# %% [markdown]
# ### test 3

# %%
np.random.seed(212)

# G = nx.erdos_renyi_graph(8, .3)
G = nx.barabasi_albert_graph(6, 3)
# nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)
plt.figure(figsize=(3, 3))
layout= nx.kamada_kawai_layout(G)
nx.draw(G, pos=layout, node_color='lightblue', with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
test_no = 3
category = 'BA'

layout= nx.kamada_kawai_layout(G)
posdf = pd.DataFrame.from_dict(layout, orient='index', columns=['X', 'Y'])
file_path = f'tests/pos_dfs/posdf_{category}_{test_no}_kamada_kawai.csv'
posdf.to_csv(file_path, index=False)

with open(f'tests/graph_objects/graph_{category}_{test_no}_kamada_kawai.pkl', 'wb') as f:
    pickle.dump(G, f)

# %%
posdf
# Out:
#           X         Y
# 0 -0.086015  0.174869
# 1  0.646997  0.113401
# 2 -0.270903  1.000000
# 3 -0.813119 -0.274567
# 4 -0.065768 -0.507632
# 5  0.588808 -0.506071

# %%
posdf_worse = posdf.copy(deep=True)

#here conduct changes
posdf_worse.at[4, 'X'] = 0.859596	
posdf_worse.at[4, 'Y'] = 0.8
posdf_worse.at[3, 'Y'] = 0.9	
# posdf_worse.at[0, 'Y'] = -0.9
# posdf_worse.at[0, 'X'] = 0.8

# %%
positions = {i: (posdf_worse.loc[i, 'X'], posdf_worse.loc[i, 'Y']) for i in range(len(posdf_worse))}

# Draw the graph
plt.figure(figsize=(3, 3))
nx.draw(G, pos=positions, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500, font_size=10)
plt.title('Graph with Positions from posd_better DataFrame')
plt.show()

# %%
file_path = f'tests/pos_dfs/posdfworse_{category}_{test_no}_kamada_kawai.csv'
posdf_worse.to_csv(file_path, index=False)

# %% [markdown]
# ### test 4

# %%
np.random.seed(212)

# G = nx.erdos_renyi_graph(8, .3)
G = nx.barabasi_albert_graph(7, 2)
# nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)
plt.figure(figsize=(3, 3))
layout= nx.kamada_kawai_layout(G)
nx.draw(G, pos=layout, node_color='lightblue', with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
#todo CHANGE THIS before running
test_no = 4
category = 'BA'

layout= nx.kamada_kawai_layout(G)
posdf = pd.DataFrame.from_dict(layout, orient='index', columns=['X', 'Y'])
file_path = f'tests/pos_dfs/posdf_{category}_{test_no}_kamada_kawai.csv'
posdf.to_csv(file_path, index=False)

with open(f'tests/graph_objects/graph_{category}_{test_no}_kamada_kawai.pkl', 'wb') as f:
    pickle.dump(G, f)

posdf
# Out:
#           X         Y
# 0 -0.072615 -0.183705
# 1  0.403670  0.068103
# 2  0.040243  0.925531
# 3 -0.572718  0.537082
# 4 -0.997153 -0.200245
# 5  0.198573 -0.924749
# 6  1.000000 -0.222016

# %%
posdf_worse = posdf.copy(deep=True)

#here conduct changes
posdf_worse.at[5, 'X'] = -.9
posdf_worse.at[5, 'Y'] = .9
posdf_worse.at[4, 'X'] = .8

positions = {i: (posdf_worse.loc[i, 'X'], posdf_worse.loc[i, 'Y']) for i in range(len(posdf_worse))}

# Draw the graph
plt.figure(figsize=(3, 3))
nx.draw(G, pos=positions, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500, font_size=10)
plt.title('Graph with Positions from posd_better DataFrame')
plt.show()

# %%
file_path = f'tests/pos_dfs/posdfworse_{category}_{test_no}_kamada_kawai.csv'
posdf_worse.to_csv(file_path, index=False)

# %% [markdown]
# # ER

# %% [markdown]
# ### test 1

# %%
np.random.seed(212)

G = nx.erdos_renyi_graph(6, .5)
plt.figure(figsize=(5,5))
nx.draw(G, with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
plt.figure(figsize=(3, 3))
layout= nx.kamada_kawai_layout(G)
nx.draw(G, pos=layout, node_color='lightblue', with_labels=True, edge_color='gray', node_size=300, font_size=10)

# %%
layout= nx.kamada_kawai_layout(G)
posdf = pd.DataFrame.from_dict(layout, orient='index', columns=['X', 'Y'])
file_path = 'tests/pos_dfs/posdf_ER_1_kamada_kawai.csv'
posdf.to_csv(file_path, index=False)

with open('tests/graph_objects/graph_ER_1_kamada_kawai.pkl', 'wb') as f:
    pickle.dump(G, f)

# %%
posdf
# Out:
#           X         Y
# 0  0.588604  0.255092
# 1  0.246283  0.886986
# 2 -0.312247 -0.105385
# 3 -0.535409  0.638692
# 4 -0.409376 -1.000000
# 5  0.422145 -0.675384

# %%
posdf_worse = posdf.copy(deep=True)
posdf_worse.at[2, 'X'] = .2
posdf_worse.at[1, 'Y'] = .05
posdf_worse.at[3, 'X'] =0.588604
posdf_worse.at[4, 'X'] = 0
posdf_worse.at[4, 'Y'] = .8

# %%
positions = {i: (posdf_worse.loc[i, 'X'], posdf_worse.loc[i, 'Y']) for i in range(len(posdf_worse))}

# Draw the graph
plt.figure(figsize=(3, 3))
nx.draw(G, pos=positions, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500, font_size=10)
plt.title('Graph with Positions from posd_better DataFrame')
plt.show()

# %%
file_path = 'tests/pos_dfs/posdfworse_ER_1_kamada_kawai.csv'
posdf_worse.to_csv(file_path, index=False)

# %% [markdown]
# # TESTING

# %%
def calculate_metric(G, posdf):
    print(node_distribution_raw(posdf))
    print(edge_length_sum(G, posdf))
    print(measure_communities_closeness(G, posdf))
    print(measure_graph_symmetry(G, posdf))
    values = [
        node_distribution_raw(posdf),
        edge_length_sum(G, posdf),
        measure_communities_closeness(G, posdf),
        measure_graph_symmetry(G, posdf)
    ]

    # Calculate the min and max values
    min_value = min(values)
    max_value = max(values)

    # Rescale the values to be in the range 0 to 1
    rescaled_values = [(value - min_value) / (max_value - min_value) for value in values]

    # Print the rescaled values
    for i, rescaled_value in enumerate(rescaled_values):
        print(f"Rescaled value {i+1}: {rescaled_value}")

    score = -0.42*node_distribution_raw(posdf) +0.34*edge_length_sum(G, posdf) + 0.39*measure_communities_closeness(G, posdf) -0.47*measure_graph_symmetry(G, posdf)
    score = -0.42*rescaled_values[0] +0.34*rescaled_values[1] + 0.39*rescaled_values[2] -0.47*rescaled_values[3]

    return score

# %%
calculate_metric(G, posdf)
# Out:
# 13.997659310439426
# 7.191531301409244
# 0.02437330280630309
# 0.9472269049784894
# Rescaled value 1: 1.0
# Rescaled value 2: 0.512918578685627
# Rescaled value 3: 0.0
# Rescaled value 4: 0.06604413605132417
# -0.2766484271910092

# %%
calculate_metric(G, posdf_worse)
# Out:
# 26.496380357719097
# 5.519775408949778
# 0.08428193394794402
# 0.9401154320895594
# Rescaled value 1: 1.0
# Rescaled value 2: 0.20579559366285854
# Rescaled value 3: 0.0
# Rescaled value 4: 0.03240308605587191
# -0.36525894860088787

# %% [markdown]
# wyzszy score to lepszy graf
# negatywna korelacja ze scorem - im wyzszy komponent tylko nizszy score
